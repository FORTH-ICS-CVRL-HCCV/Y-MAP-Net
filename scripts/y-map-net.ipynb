# %%
#<----- Click this play button to setup Y-MAP-Net!

#If you deploy this on your PC, run : jupyter notebook y-map-net.ipynb
#   and remove --collab from the setup.sh invocation 2 lines below..!
import os
# !git clone https://github.com/FORTH-ICS-CVRL-HCCV/Y-MAP-Net && cd Y-MAP-Net/
# or 
#!wget http://ammar.gr/ymapnet/ymapnet.zip && unzip -o ymapnet.zip -d Y-MAP-Net
# !Y-MAP-Net/scripts/setup.sh --collab
#At this point Y-Map-Net should be installed..
print("Y-MAP-Net setup is finished, you can run the next cell now..")

# %%
#<------ Click to download a video file and then run MAP-YNet on it
# !wget -P Y-Map-Net http://ammar.gr/mocapnet/shuffle.webm
# !Y-MAP-Net/runYMAPNet.sh --from shuffle.webm --collab
print("Y-MAP-Net execution is finished, you can run the next cell now..")

# %%
#<----- Click to see the generated video file of the last MAP-YNet run!
from IPython.display import Video
import os
if (not os.path.isfile("Y-MAP-Net/shuffle.webm_illustration.mp4")):
   print("Please execute the previous cells and wait for them to complete before seeing this visualization!")
   exit

Video("Y-MAP-Net/shuffle.webm_illustration.mp4",embed=True)
